# %%
import numpy as np 
import pandas as pd

# %%
subjects = ["sub-01","sub-03","sub-04", "sub-05", "sub-06", "sub-07", "sub-09","sub-11", "sub-13", "sub-14", "sub-15", "sub-16", "sub-17"]

# excluded because of task: 08 
# excluded because of non normal brain: 12
# check 01 and 02 and 10

# %%
df_ee = pd.DataFrame()

# %%
# PRETRAINED MODEL 

# Define tasks
tasks = ["open", "no_stim", "blink", "all"]

# Initialize list to store data rows
results = []

for subject in subjects: #f'/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_0{run+1}_ee_pretrained.tsv.gz'
    for task in tasks:
        # Load data for each run
        ee_run_01 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_01_ee_pretrained.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_02 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_02_ee_pretrained.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_03 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_03_ee_pretrained.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        # Combine runs and compute statistics
        all_ee = np.concatenate([ee_run_01, ee_run_02, ee_run_03])
        mean_ee = np.mean(all_ee)
        perc_ee = np.percentile(all_ee, 75)
        
        # Append result to the list
        results.append({
            'subject': subject,
            'task': task,
            'model': 'pretrained',
            'mean': mean_ee,
            '75_perc': perc_ee
        })

# Convert to DataFrame
df_ee = pd.DataFrame(results)

# Optional: display or save
print(df_ee.head())
# df_ee.to_csv('ee_pretrained_summary.csv', index=False)
# Out:
#   subject     task       model      mean   75_perc
# 0  sub-03     open  pretrained  6.121932  8.928498
# 1  sub-03  no_stim  pretrained  4.107883  6.797724
# 2  sub-03    blink  pretrained  5.710099  9.131850
# 3  sub-03      all  pretrained  4.825110  7.356007
# 4  sub-04     open  pretrained  4.573605  6.210160

# %%
# CALIB MODEL 

# Define tasks
tasks = ["open", "no_stim", "blink", "all"]

# Initialize list to store data rows
results = []

for subject in subjects:
    for task in tasks:
        # Load data for each run
        ee_run_01 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_01_ee_calibpretrained.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_02 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_02_ee_calibpretrained.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_03 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_03_ee_calibpretrained.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        # Combine runs and compute statistics
        all_ee = np.concatenate([ee_run_01, ee_run_02, ee_run_03])
        mean_ee = np.mean(all_ee)
        perc_ee = np.percentile(all_ee, 75)
        
        # Append result to the list
        results.append({
            'subject': subject,
            'task': task,
            'model': 'pt_calib',
            'mean': mean_ee,
            '75_perc': perc_ee
        })

# Convert to DataFrame
df_ee_calib = pd.DataFrame(results)

# Optional: display or save
print(df_ee_calib.head())
# Concatenate
df_ee = pd.concat([df_ee, df_ee_calib], ignore_index=True)
# Out:
#   subject     task     model      mean   75_perc
# 0  sub-03     open  pt_calib  4.955977  7.252760
# 1  sub-03  no_stim  pt_calib  4.014739  5.582186
# 2  sub-03    blink  pt_calib  4.604307  7.266991
# 3  sub-03      all  pt_calib  4.483146  6.751418
# 4  sub-04     open  pt_calib  4.908493  6.004840

# %%
# FINE TUNED MODEL 

# Define tasks
tasks = ["open", "no_stim", "blink", "all"]

# Initialize list to store data rows
gaze_results = []

for subject in subjects:
    for task in tasks:
        # Load data for each run
        ee_run_01 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_01_ee_pt_gaze.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_02 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_02_ee_pt_gaze.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_03 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_03_ee_pt_gaze.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        # Combine runs and compute statistics
        all_ee = np.concatenate([ee_run_01, ee_run_02, ee_run_03])
        mean_ee = np.mean(all_ee)
        perc_ee = np.percentile(all_ee, 75)
        
        # Append result to the list
        gaze_results.append({
            'subject': subject,
            'task': task,
            'model': 'pt_gaze',
            'mean': mean_ee,
            '75_perc': perc_ee
        })

# Convert to DataFrame
df_gaze = pd.DataFrame(gaze_results)
print(df_gaze.head())

# Concatenate
df_ee = pd.concat([df_ee, df_gaze], ignore_index=True)
# Out:
#   subject     task    model      mean   75_perc
# 0  sub-03     open  pt_gaze  2.424561  3.192744
# 1  sub-03  no_stim  pt_gaze  5.560797  7.729100
# 2  sub-03    blink  pt_gaze  3.817797  5.781002
# 3  sub-03      all  pt_gaze  5.501682  8.698855
# 4  sub-04     open  pt_gaze  5.160110  7.245127

# %%
# FINE TUNED MODEL (CALIB + CLOSED)

# Define tasks
tasks = ["open", "no_stim", "blink", "all"]

# Initialize list to store data rows
ft_gaze_results = []

for subject in subjects:
    for task in tasks:
        # Load data for each run
        ee_run_01 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_01_ee_ft_gaze.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_02 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_02_ee_ft_gaze.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        ee_run_03 = pd.read_csv(
            f"/Users/sinakling/disks/meso_shared/deepmreye/derivatives/pp_data/{subject}/eyetracking/timeseries/{subject}_task-DeepMReyeClosed_subtask-{task}_run_03_ee_ft_gaze.tsv.gz",
            compression='gzip', delimiter='\t')[['ee']].to_numpy()
        
        # Combine runs and compute statistics
        all_ee = np.concatenate([ee_run_01, ee_run_02, ee_run_03])
        mean_ee = np.mean(all_ee)
        perc_ee = np.percentile(all_ee, 75)
        
        # Append result to the list
        ft_gaze_results.append({
            'subject': subject,
            'task': task,
            'model': 'ft_gaze',
            'mean': mean_ee,
            '75_perc': perc_ee
        })

# Convert to DataFrame
df_ft_gaze = pd.DataFrame(ft_gaze_results)
print(df_ft_gaze.head())

# Concatenate
df_ee = pd.concat([df_ee, df_ft_gaze], ignore_index=True)
# Out:
#   subject     task    model      mean    75_perc
# 0  sub-01     open  ft_gaze  5.511374   9.242141
# 1  sub-01  no_stim  ft_gaze  7.184318  11.739741
# 2  sub-01    blink  ft_gaze  6.555805   9.952775
# 3  sub-01      all  ft_gaze  6.930670  10.890161
# 4  sub-03     open  ft_gaze  2.440003   3.363219

# %%
df_ee = df_ee[df_ee["subject"] != 'sub-11']
df_ee = df_ee[df_ee["subject"] != 'sub-04']
df_ee = df_ee[df_ee["subject"] != 'sub-05']

# %%
# CORRELATION (all models)
df_corr = pd.read_csv('/Users/sinakling/Desktop/correlation_closed.csv')

# %%
df_corr = df_corr[df_corr["subject"] != 'sub-04']
df_corr = df_corr[df_corr["subject"] != 'sub-11']

# %%
from scipy.stats import permutation_test
import pandas as pd

def paired_permutation_tests(df, model_a, model_b):
    """
    Run paired permutation tests between two models for each task.

    Parameters:
        df (pd.DataFrame): DataFrame with columns ['subject', 'task', 'model', 'mean']
        model_a (str): Name of the first model
        model_b (str): Name of the second model

    Returns:
        pd.DataFrame: A DataFrame with task, p-value, and effect size (mean diff)
    """
    results = []

    # Group only by task
    grouped = df.groupby('task')

    for task, group in grouped:
        # Filter to the two models of interest
        group_filtered = group[group['model'].isin([model_a, model_b])]

        # Pivot: subjects as rows, models as columns
        pivoted = group_filtered.pivot(index='subject', columns='model', values='mean').dropna()

        if pivoted.shape[0] < 2:
            continue  # Not enough subjects with data for both models

        a_values = pivoted[model_a].values
        b_values = pivoted[model_b].values

        # Paired permutation test on mean difference
        result = permutation_test(
            (a_values, b_values),
            statistic=lambda x, y: (x - y).mean(),
            permutation_type='samples',
            vectorized=False,
            alternative='two-sided',
            n_resamples=10000
        )

        results.append({
            'task': task,
            'model_a': model_a,
            'model_b': model_b,
            'mean_diff': (a_values - b_values).mean(),
            'p_value': result.pvalue,
            'n_subjects': len(pivoted)
        })

    return pd.DataFrame(results)

# %%
# Run paired permutation tests for ee 

sig_df_pt_vs_pt_calib = paired_permutation_tests(df_ee, model_a='pretrained', model_b='pt_calib')

# Run paired permutation tests for another pairing (e.g., pt vs pt_gaze) and append to the same dataframe
sig_df_pt_vs_gaze = paired_permutation_tests(df_ee, model_a='pretrained', model_b='pt_gaze')

sig_df_calib_vs_gaze = paired_permutation_tests(df_ee, model_a='pt_calib', model_b='pt_gaze')

sig_df_calib_vs_ft_gaze = paired_permutation_tests(df_ee, model_a='pt_calib', model_b='pt_gaze')

# Append the results from both pairings
sig_df = pd.concat([sig_df_pt_vs_pt_calib, sig_df_pt_vs_gaze, sig_df_calib_vs_gaze,sig_df_calib_vs_ft_gaze ], ignore_index=True)

# Show the combined dataframe with the significance results
print(sig_df)
# Out:
#        task     model_a   model_b  mean_diff   p_value  n_subjects
# 0       all  pretrained  pt_calib   0.420649  0.003906           9
# 1     blink  pretrained  pt_calib   1.292253  0.003906           9
# 2   no_stim  pretrained  pt_calib   0.445537  0.011719           9
# 3      open  pretrained  pt_calib   1.416612  0.003906           9
# 4       all  pretrained   pt_gaze  -0.309306  0.328125           9
# 5     blink  pretrained   pt_gaze   2.047444  0.007812           9
# 6   no_stim  pretrained   pt_gaze  -0.528729  0.160156           9
# 7      open  pretrained   pt_gaze   2.803984  0.003906           9
# 8       all    pt_calib   pt_gaze  -0.729956  0.023438           9
# 9     blink    pt_calib   pt_gaze   0.755192  0.058594           9
# 10  no_stim    pt_calib   pt_gaze  -0.974266  0.019531           9
# 11     open    pt_calib   pt_gaze   1.387372  0.015625           9
# 12      all    pt_calib   pt_gaze  -0.729956  0.023438           9
# ...

# %%
# Run paired permutation tests for corr

sig_df_pt_vs_pt_calib = paired_permutation_tests(df_corr, model_a='pretrained', model_b='calibpretrained')

# Run paired permutation tests for another pairing (e.g., pt vs pt_gaze) and append to the same dataframe
sig_df_pt_vs_gaze = paired_permutation_tests(df_corr, model_a='pretrained', model_b='pt_gaze')

sig_df_calib_vs_gaze = paired_permutation_tests(df_corr, model_a='calibpretrained', model_b='pt_gaze')

# Append the results from both pairings
sig_df = pd.concat([sig_df_pt_vs_pt_calib, sig_df_pt_vs_gaze, sig_df_calib_vs_gaze], ignore_index=True)

# Show the combined dataframe with the significance results
print(sig_df)
# Out:
#        task          model_a          model_b  mean_diff   p_value  n_subjects
# 0       all       pretrained  calibpretrained  -0.051516  0.000977          12
# 1     blink       pretrained  calibpretrained  -0.044657  0.002441          12
# 2   no_stim       pretrained  calibpretrained  -0.008130  0.013672          12
# 3      open       pretrained  calibpretrained  -0.009859  0.052734          12
# 4       all       pretrained          pt_gaze  -0.080697  0.000488          12
# 5     blink       pretrained          pt_gaze  -0.048290  0.005859          12
# 6   no_stim       pretrained          pt_gaze  -0.026823  0.000488          12
# 7      open       pretrained          pt_gaze  -0.039376  0.000488          12
# 8       all  calibpretrained          pt_gaze  -0.029181  0.029785          12
# 9     blink  calibpretrained          pt_gaze  -0.003633  0.794434          12
# 10  no_stim  calibpretrained          pt_gaze  -0.018693  0.000488          12
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

# Define color and name mappings
model_name_map = {
    "pretrained": "DeepMreye",
    "pt_gaze": "DeepMreye + Closed",
    "pt_calib": "DeepMreye + Calib", 
    "ft_gaze": "DeepMreye + Calib + Closed"
}

bar_color = 'rgba(66, 129, 164, 0.25)' 

colormap_subject_dict = {
    'sub-01': '#AA0DFE', 'sub-02': '#3283FE', 'sub-03': '#85660D', 'sub-04': '#782AB6',
    'sub-05': '#565656', 'sub-06': '#1C8356', 'sub-07': '#16FF32', 'sub-08': '#F7E1A0',
    'sub-09': '#E2E2E2', 'sub-11': '#1CBE4F', 'sub-13': '#DEA0FD', 'sub-14': '#FBE426', 
    'sub-15': '#325A9B', 'sub-16': '#FEAF16', 'sub-17': '#F8A19F'
}

task_labels = ["<b>Eyes Open + Vision<b>", "<b>Eyes Blink + Vision<b>", "<b>Eyes Open + No Vision<b>"]
task_names = ["open", "no_stim", "blink", "all"]


comparisons = [
    ("pretrained", "pt_calib"),
    ("pretrained", "pt_gaze"),
    ("pt_calib", "ft_gaze")
]

fig = make_subplots(
    rows=4, cols=3,
    subplot_titles=[f"{label}" for label in task_labels for _ in range(3)] + ["<b>All Tasks<b>"] * 3
)


# Keep track of subjects already shown in legend
shown_subjects = set()

for i, task in enumerate(task_names):
    for j, (model_a, model_b) in enumerate(comparisons):
        row = i + 1
        col = j + 1

        df_plot = df_ee[
            (df_ee["task"] == task) &
            (df_ee["model"].isin([model_a, model_b]))
        ]

        df_pivot = df_plot.pivot(index="subject", columns="model", values="mean")[[model_a, model_b]].dropna()

        means = df_pivot.mean()
        stderrs = df_pivot.sem()
        x_vals = [0, 1]

        fig.add_trace(go.Bar(
            x=x_vals,
            y=means.values,
            error_y=dict(type="data", array=stderrs.values),
            marker_color=bar_color,
            width=0.25,
            showlegend=False
        ), row=row, col=col)

        # Add connecting lines per subject
        for subject, row_data in df_pivot.iterrows():
            color = colormap_subject_dict.get(subject, 'gray')
            show_legend = subject not in shown_subjects
            shown_subjects.add(subject)

            fig.add_trace(go.Scatter(
                x=x_vals,
                y=row_data.values,
                mode='lines+markers',
                line=dict(color=color, width=1.5),
                marker=dict(size=4),
                name=subject,
                opacity=0.9,
                showlegend=show_legend
            ), row=row, col=col)

        # Add significance marker if p < 0.05
        sig_row = sig_df[
            (sig_df.task == task) &
            (sig_df.model_a == model_a) &
            (sig_df.model_b == model_b)
        ]

        if not sig_row.empty and sig_row.iloc[0].p_value < 0.05:
            y_vals = means.values
            max_y = max(y_vals)
            line_y = max_y + 0.5

            fig.add_shape(
                type="line",
                x0=0,
                x1=1,
                y0=line_y,
                y1=line_y,
                line=dict(color="black", width=1),
                row=row, col=col
            )
            fig.add_trace(go.Scatter(
                x=[0.5],
                y=[line_y + 0.9],
                text=["*"],
                mode="text",
                showlegend=False
            ), row=row, col=col)

# Layout
fig.update_layout(
    height=1800,
    width=1300,
    title_text="How well does Calib generalize?",
    template="simple_white",
    showlegend=True,
    font=dict(size=16, family="Arial"),
    margin=dict(t=150)
)

# Axis formatting
for i in range(1, 5):
    for j in range(1, 4):  # 3 columns
        if j == 1:
            model_b_label = model_name_map["pt_calib"]
        elif j == 2:
            model_b_label = model_name_map["pt_gaze"]
        else:
            model_b_label = model_name_map["pt_gaze"]  
        model_a_label = model_name_map["pretrained"] if j in [1, 2] else model_name_map["pt_calib"]

        fig.update_yaxes(range=[0, 10], title_text="Euclidean Error (dva)", row=i, col=j)
        fig.update_xaxes(
            tickvals=[0, 1],
            ticktext=[model_a_label, model_b_label],
            row=i, col=j
        )


fig.show()
#fig.write_image("/Users/sinakling/disks/meso_shared/deepmreye/derivatives/int_deepmreye/deepmreye_closed/figures/group/euclidean_error_barplots.pdf")

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

# Define color and name mappings
model_name_map = {
    "pretrained": "DeepMreye",
    "pt_gaze": "DeepMreye + Closed",
    "calibpretrained": "DeepMreye + Calib"
}

bar_color = 'rgba(66, 129, 164, 0.25)' 

colormap_subject_dict = {
    'sub-01': '#AA0DFE', 'sub-02': '#3283FE', 'sub-03': '#85660D', 'sub-04': '#782AB6',
    'sub-05': '#565656', 'sub-06': '#1C8356', 'sub-07': '#16FF32', 'sub-08': '#F7E1A0',
    'sub-09': '#E2E2E2', 'sub-11': '#1CBE4F', 'sub-13': '#DEA0FD', 'sub-14': '#FBE426', 
    'sub-15': '#325A9B', 'sub-16': '#FEAF16', 'sub-17': '#F8A19F'
}

task_labels = ["<b>Eyes Open + Vision<b>", "<b>Eyes Blink + Vision<b>", "<b>Eyes Open + No Vision<b>"]
task_names = ["open", "no_stim", "blink", "all"]


comparisons = [
    ("pretrained", "calibpretrained"),
    ("pretrained", "pt_gaze"),
    ("calibpretrained", "pt_gaze")
]

fig = make_subplots(
    rows=4, cols=3,
    subplot_titles=[f"{label}" for label in task_labels for _ in range(3)] + ["<b>All Tasks<b>"] * 3
)


# Keep track of subjects already shown in legend
shown_subjects = set()

for i, task in enumerate(task_names):
    for j, (model_a, model_b) in enumerate(comparisons):
        row = i + 1
        col = j + 1

        df_plot = df_corr[
            (df_corr["task"] == task) &
            (df_corr["model"].isin([model_a, model_b]))
        ]

        df_pivot = df_plot.pivot(index="subject", columns="model", values="mean_pearson")[[model_a, model_b]].dropna()

        means = df_pivot.mean()
        stderrs = df_pivot.sem()
        x_vals = [0, 1]

        fig.add_trace(go.Bar(
            x=x_vals,
            y=means.values,
            error_y=dict(type="data", array=stderrs.values),
            marker_color=bar_color,
            width=0.25,
            showlegend=False
        ), row=row, col=col)

        # Add connecting lines per subject
        for subject, row_data in df_pivot.iterrows():
            color = colormap_subject_dict.get(subject, 'gray')
            show_legend = subject not in shown_subjects
            shown_subjects.add(subject)

            fig.add_trace(go.Scatter(
                x=x_vals,
                y=row_data.values,
                mode='lines+markers',
                line=dict(color=color, width=1.5),
                marker=dict(size=4),
                name=subject,
                opacity=0.9,
                showlegend=show_legend
            ), row=row, col=col)

        # Add significance marker if p < 0.05
        sig_row = sig_df[
            (sig_df.task == task) &
            (sig_df.model_a == model_a) &
            (sig_df.model_b == model_b)
        ]

        if not sig_row.empty and sig_row.iloc[0].p_value < 0.05:
            y_vals = means.values
            max_y = max(y_vals)
            line_y = max_y + 0.05

            fig.add_shape(
                type="line",
                x0=0,
                x1=1,
                y0=line_y,
                y1=line_y,
                line=dict(color="black", width=1),
                row=row, col=col
            )
            fig.add_trace(go.Scatter(
                x=[0.5],
                y=[line_y + 0.1],
                text=["*"],
                mode="text",
                showlegend=False
            ), row=row, col=col)

# Layout
fig.update_layout(
    height=1800,
    width=1300,
    title_text="How well does Calib generalize?",
    template="simple_white",
    showlegend=True,
    font=dict(size=16, family="Arial"),
    margin=dict(t=150)
)

# Axis formatting
for i in range(1, 5):
    for j in range(1, 4):  # 3 columns
        if j == 1:
            model_b_label = model_name_map["calibpretrained"]
        elif j == 2:
            model_b_label = model_name_map["pt_gaze"]
        else:
            model_b_label = model_name_map["pt_gaze"]  
        model_a_label = model_name_map["pretrained"] if j in [1, 2] else model_name_map["calibpretrained"]

        fig.update_yaxes(range=[0, 1.15], title_text="Correlation", row=i, col=j)
        fig.update_xaxes(
            tickvals=[0, 1],
            ticktext=[model_a_label, model_b_label],
            row=i, col=j
        )


fig.show()
fig.write_image("/Users/sinakling/disks/meso_shared/deepmreye/derivatives/int_deepmreye/deepmreye_closed/figures/group/correlation_barplots.pdf")
