# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def adapt_evaluation(participant_evaluation):
    pred_y = participant_evaluation["pred_y"]
    pred_y_median = np.nanmedian(pred_y, axis=1)
    pred_uncertainty = abs(participant_evaluation["euc_pred"])
    pred_uncertainty_median = np.nanmedian(pred_uncertainty, axis=1)
    df_pred_median = pd.DataFrame(
        np.concatenate(
            (pred_y_median, pred_uncertainty_median[..., np.newaxis]), axis=1),
        columns=["X", "Y", "Uncertainty"],
    )
    # With subTR
    subtr_values = np.concatenate((pred_y, pred_uncertainty[..., np.newaxis]),
                                  axis=2)
    index = pd.MultiIndex.from_product(
        [range(subtr_values.shape[0]),
         range(subtr_values.shape[1])],
        names=["TR", "subTR"])
    df_pred_subtr = pd.DataFrame(subtr_values.reshape(-1,
                                                      subtr_values.shape[-1]),
                                 index=index,
                                 columns=["X", "Y", "pred_error"])

    return df_pred_median, df_pred_subtr

# %%
# PRETRAINED 
evaluation_closed = np.load("/Users/sinakling/disks/meso_shared/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pred/evaluation_dict_closed_pretrained.npy", allow_pickle=True).item()
print(evaluation_closed.keys())

sub_01_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-01_DeepMReyeClosed_no_label.npz"]
df_pred_median_1, df_pred_subtr_1 = adapt_evaluation(sub_01_closed)

sub_02_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-02_DeepMReyeClosed_no_label.npz"]
df_pred_median_2, df_pred_subtr_2 = adapt_evaluation(sub_02_closed)

sub_03_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-03_DeepMReyeClosed_no_label.npz"]
df_pred_median_3, df_pred_subtr_3 = adapt_evaluation(sub_03_closed)

sub_04_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-04_DeepMReyeClosed_no_label.npz"]
df_pred_median_4, df_pred_subtr_4 = adapt_evaluation(sub_04_closed)

sub_06_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-06_DeepMReyeClosed_no_label.npz"]
df_pred_median_6, df_pred_subtr_6 = adapt_evaluation(sub_06_closed)

sub_07_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-07_DeepMReyeClosed_no_label.npz"]
df_pred_median_7, df_pred_subtr_7 = adapt_evaluation(sub_07_closed)

sub_08_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-08_DeepMReyeClosed_no_label.npz"]
df_pred_median_8, df_pred_subtr_8 = adapt_evaluation(sub_08_closed)

sub_09_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-09_DeepMReyeClosed_no_label.npz"]
df_pred_median_9, df_pred_subtr_9 = adapt_evaluation(sub_09_closed)

sub_10_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-10_DeepMReyeClosed_no_label.npz"]
df_pred_median_10, df_pred_subtr_10 = adapt_evaluation(sub_10_closed)

sub_11_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-11_DeepMReyeClosed_no_label.npz"]
df_pred_median_11, df_pred_subtr_11 = adapt_evaluation(sub_11_closed)

sub_13_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-13_DeepMReyeClosed_no_label.npz"]
df_pred_median_13, df_pred_subtr_13 = adapt_evaluation(sub_13_closed)

sub_14_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-14_DeepMReyeClosed_no_label.npz"]
df_pred_median_14, df_pred_subtr_14 = adapt_evaluation(sub_14_closed)

sub_15_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-15_DeepMReyeClosed_no_label.npz"]
df_pred_median_15, df_pred_subtr_15 = adapt_evaluation(sub_15_closed)

sub_16_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-16_DeepMReyeClosed_no_label.npz"]
df_pred_median_16, df_pred_subtr_16 = adapt_evaluation(sub_16_closed)

sub_17_closed = evaluation_closed["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-17_DeepMReyeClosed_no_label.npz"]
df_pred_median_17, df_pred_subtr_17 = adapt_evaluation(sub_17_closed)

# Invert Y axis 

# Multiply the column by -1 for each dataframe
df_pred_median_1["Y"]  *= -1
df_pred_median_3["Y"]  *= -1
df_pred_median_4["Y"]  *= -1
df_pred_median_6["Y"]  *= -1
df_pred_median_7["Y"]  *= -1
df_pred_median_8["Y"]  *= -1
df_pred_median_9["Y"]  *= -1
df_pred_median_10["Y"] *= -1
df_pred_median_11["Y"] *= -1
df_pred_median_13["Y"] *= -1
df_pred_median_14["Y"] *= -1
df_pred_median_15["Y"] *= -1
df_pred_median_16["Y"] *= -1
df_pred_median_17["Y"] *= -1
# Out:
# dict_keys(['/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-13_DeepMReyeClosed_no_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-09_DeepMReyeClosed_no_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-02_DeepMReyeClosed_no_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-01_DeepMReyeClosed_no_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-11_DeepMReyeClosed_no_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-16_DeepMReyeClosed_no_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_pretrained/sub-15_DeepMReyeClosed_no_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmre
# ...

# %%
# CALIB FINETUNED
evaluation_closed_calib = np.load("/Users/sinakling/disks/meso_shared/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pred/evaluation_dict_closed_calibpretrained.npy", allow_pickle=True).item()

sub_01_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-01_DeepMReyeClosed_no_label.npz"]
df_pred_median_1_calib, df_pred_subtr_1_calib = adapt_evaluation(sub_01_closed_calib)

sub_02_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-02_DeepMReyeClosed_no_label.npz"]
df_pred_median_2_calib, df_pred_subtr_2_calib = adapt_evaluation(sub_02_closed_calib)

sub_03_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-03_DeepMReyeClosed_no_label.npz"]
df_pred_median_3_calib, df_pred_subtr_3_calib = adapt_evaluation(sub_03_closed_calib)

sub_04_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-04_DeepMReyeClosed_no_label.npz"]
df_pred_median_4_calib, df_pred_subtr_4_calib = adapt_evaluation(sub_04_closed_calib)

sub_06_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-06_DeepMReyeClosed_no_label.npz"]
df_pred_median_6_calib, df_pred_subtr_6_calib = adapt_evaluation(sub_06_closed_calib)

sub_07_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-07_DeepMReyeClosed_no_label.npz"]
df_pred_median_7_calib, df_pred_subtr_7_calib = adapt_evaluation(sub_07_closed_calib)

sub_08_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-08_DeepMReyeClosed_no_label.npz"]
df_pred_median_8_calib, df_pred_subtr_8_calib = adapt_evaluation(sub_08_closed_calib)

sub_09_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-09_DeepMReyeClosed_no_label.npz"]
df_pred_median_9_calib, df_pred_subtr_9_calib = adapt_evaluation(sub_09_closed_calib)

sub_10_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-10_DeepMReyeClosed_no_label.npz"]
df_pred_median_10_calib, df_pred_subtr_11_calib = adapt_evaluation(sub_10_closed_calib)

sub_11_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-11_DeepMReyeClosed_no_label.npz"]
df_pred_median_11_calib, df_pred_subtr_11_calib = adapt_evaluation(sub_11_closed_calib)

sub_13_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-13_DeepMReyeClosed_no_label.npz"]
df_pred_median_13_calib, df_pred_subtr_13_calib = adapt_evaluation(sub_13_closed_calib)

sub_14_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-14_DeepMReyeClosed_no_label.npz"]
df_pred_median_14_calib, df_pred_subtr_14_calib = adapt_evaluation(sub_14_closed_calib)

sub_15_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-15_DeepMReyeClosed_no_label.npz"]
df_pred_median_15_calib, df_pred_subtr_15_calib = adapt_evaluation(sub_15_closed_calib)

sub_16_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-16_DeepMReyeClosed_no_label.npz"]
df_pred_median_16_calib, df_pred_subtr_16_calib = adapt_evaluation(sub_16_closed_calib)

sub_17_closed_calib = evaluation_closed_calib["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_calibpretrained/sub-17_DeepMReyeClosed_no_label.npz"]
df_pred_median_17_calib, df_pred_subtr_17_calib = adapt_evaluation(sub_17_closed_calib)

# %%
# PRETRAINED FT GAZE
evaluation_closed_pt_gaze = np.load("/Users/sinakling/disks/meso_shared/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pred/evaluation_dict_gaze_closed.npy", allow_pickle=True).item()
print(evaluation_closed_pt_gaze.keys())

sub_01_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-01_DeepMReyeClosed_label.npz"]
df_pred_median_1_pt_gaze, df_pred_subtr_1_pt_gaze = adapt_evaluation(sub_01_closed_pt_gaze)

sub_02_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-02_DeepMReyeClosed_label.npz"]
df_pred_median_2_pt_gaze, df_pred_subtr_2_pt_gaze = adapt_evaluation(sub_02_closed_pt_gaze)

sub_03_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-03_DeepMReyeClosed_label.npz"]
df_pred_median_3_pt_gaze, df_pred_subtr_3_pt_gaze = adapt_evaluation(sub_03_closed_pt_gaze)

sub_04_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-04_DeepMReyeClosed_label.npz"]
df_pred_median_4_pt_gaze, df_pred_subtr_4_pt_gaze = adapt_evaluation(sub_04_closed_pt_gaze)

sub_05_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-05_DeepMReyeClosed_label.npz"]
df_pred_median_5_pt_gaze, df_pred_subtr_5_pt_gaze = adapt_evaluation(sub_05_closed_pt_gaze)

sub_06_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-06_DeepMReyeClosed_label.npz"]
df_pred_median_6_pt_gaze, df_pred_subtr_6_pt_gaze = adapt_evaluation(sub_06_closed_pt_gaze)

sub_07_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-07_DeepMReyeClosed_label.npz"]
df_pred_median_7_pt_gaze, df_pred_subtr_7_pt_gaze = adapt_evaluation(sub_07_closed_pt_gaze)

sub_09_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-09_DeepMReyeClosed_label.npz"]
df_pred_median_9_pt_gaze, df_pred_subtr_9_pt_gaze = adapt_evaluation(sub_09_closed_pt_gaze)

sub_10_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-10_DeepMReyeClosed_label.npz"]
df_pred_median_10_pt_gaze, df_pred_subtr_10_pt_gaze = adapt_evaluation(sub_10_closed_pt_gaze)

sub_11_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-11_DeepMReyeClosed_label.npz"]
df_pred_median_11_pt_gaze, df_pred_subtr_11_pt_gaze = adapt_evaluation(sub_11_closed_pt_gaze)

sub_13_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-13_DeepMReyeClosed_label.npz"]
df_pred_median_13_pt_gaze, df_pred_subtr_13_pt_gaze = adapt_evaluation(sub_13_closed_pt_gaze)

sub_14_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-14_DeepMReyeClosed_label.npz"]
df_pred_median_14_pt_gaze, df_pred_subtr_14_pt_gaze = adapt_evaluation(sub_14_closed_pt_gaze)

sub_15_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-15_DeepMReyeClosed_label.npz"]
df_pred_median_15_pt_gaze, df_pred_subtr_15_pt_gaze = adapt_evaluation(sub_15_closed_pt_gaze)

sub_16_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-16_DeepMReyeClosed_label.npz"]
df_pred_median_16_pt_gaze, df_pred_subtr_16_pt_gaze = adapt_evaluation(sub_16_closed_pt_gaze)

sub_17_closed_pt_gaze = evaluation_closed_pt_gaze["/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-17_DeepMReyeClosed_label.npz"]
df_pred_median_17_pt_gaze, df_pred_subtr_17_pt_gaze = adapt_evaluation(sub_17_closed_pt_gaze)
# Out:
# dict_keys(['/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-10_DeepMReyeClosed_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-14_DeepMReyeClosed_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-05_DeepMReyeClosed_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-16_DeepMReyeClosed_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-17_DeepMReyeClosed_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-13_DeepMReyeClosed_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-02_DeepMReyeClosed_label.npz', '/scratch/mszinte/data/deepmreye/derivatives/int_deepmreye/deepmreye_closed/pp_data_gaze/sub-03_DeepMReyeClosed_label.n
# ...

# %% [markdown]
# # CLASSIFICATION USING FINE TUNED CLOSED

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

slice_length = 9
nTR_run = 313

task_TRs = {
    "task_1": (5, 77),
    "task_2": (82, 154),
    "task_3": (159, 231),
    "task_4": (236, 308),
}

# Define your subject DataFrames (
subject_dfs = {
    1: df_pred_median_1_calib,
    2: df_pred_median_2_calib,
    3: df_pred_median_3_calib,
    4: df_pred_median_4_calib,
    6: df_pred_median_6_calib,
    7: df_pred_median_7_calib,
    8: df_pred_median_8_calib,
    9: df_pred_median_9_calib,
    10: df_pred_median_10_calib,
    11: df_pred_median_11_calib,
    13: df_pred_median_13_calib,
    14: df_pred_median_14_calib,
    15: df_pred_median_15_calib, 
    16: df_pred_median_16_calib,
    17: df_pred_median_17_calib
}

# Labeling pattern (TR index, label)
pattern = [
    (5, 'up'), (41, 'up'), (82, 'up'), (118, 'up'), (159, 'up'), (195, 'up'), (236, 'up'), (272, 'up'),
    (14, 'right'), (50, 'right'), (91, 'right'), (127, 'right'), (168, 'right'), (204, 'right'), (245, 'right'), (281, 'right'),
    (23, 'down'), (59, 'down'), (100, 'down'), (136, 'down'), (177, 'down'), (213, 'down'), (254, 'down'), (290, 'down'),
    (32, 'left'), (68, 'left'), (109, 'left'), (145, 'left'), (186, 'left'), (222, 'left'), (263, 'left'), (299, 'left')
]

# Shift TRs by +1 (to form full triangles)
indices_and_labels = []
for i in range(3):  # 3 runs
    #indices_and_labels.extend([(tr + i * nTR_run + 2, label) for tr, label in pattern])  
    indices_and_labels.extend([(tr + i * nTR_run, label) for tr, label in pattern])

# Create slices
all_data = []
tr_indices = []

for subject_id, df in subject_dfs.items():
    df = df.copy()
    df['subject'] = subject_id

    for start_index, label in indices_and_labels:
        end_index = start_index + slice_length
        if end_index <= len(df):
            x_slice = df['X'].iloc[start_index:end_index].values
            y_slice = df['Y'].iloc[start_index:end_index].values

            if len(x_slice) == slice_length and len(y_slice) == slice_length:
                all_data.append([subject_id, x_slice, y_slice, label])
                tr_indices.append(start_index)

# Convert to DataFrame
columns = ['subject'] + [f'x{i+1}' for i in range(slice_length)] + [f'y{i+1}' for i in range(slice_length)] + ['label']
formatted_data = []

for entry in all_data:
    subject_id, x_slice, y_slice, label = entry
    formatted_data.append([subject_id] + list(x_slice) + list(y_slice) + [label])

df_final = pd.DataFrame(formatted_data, columns=columns)

# Encode labels
label_encoder = LabelEncoder()
df_final['label_encoded'] = label_encoder.fit_transform(df_final['label'])

label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mapping:", label_mapping)

# Task assignment function
def get_task_label(tr):
    tr_in_run = tr % nTR_run
    for task, (start, end) in task_TRs.items():
        if start <= tr_in_run < end:
            return task
    return "ITI"

df_final["task"] = [get_task_label(tr) for tr in tr_indices]

print(df_final.head())
# Out:
# Label Mapping: {'down': 0, 'left': 1, 'right': 2, 'up': 3}
#    subject        x1        x2        x3        x4        x5        x6  \
# 0        1  4.909222  4.655349  4.971134 -1.552459 -1.983999 -1.796518
# 1        1  4.567011  5.368581  4.593950 -1.141220 -3.018862 -2.661807
# 2        1  5.001142  4.480499  3.144464 -2.799526 -4.527882 -4.214989
# 3        1  4.388505 -0.182298  3.514063 -1.922975 -4.842231 -2.333961
# 4        1  3.919647  4.847745  5.832081 -3.935701 -5.299150 -3.587916
#
#          x7        x8        x9  ...        y3        y4        y5        y6  \
# 0  1.578479  1.217659  1.223732  ... -1.099766 -2.394497 -2.146699 -1.227670
# 1  0.877185  1.171047  0.983113  ... -1.028448 -2.523373 -2.738242 -3.388678
# 2  0.652711 -0.022895  0.123896  ... -3.327125  2.033787 -4.317341 -1.602612
# 3 -0.137545 -1.516579  0.223768  ... -3.625888  1.979789 -7.059837 -4.643696
# 4  0.496962  0.979917  0.397718  ... -1.728666 -1.387838 -2.210332 -1.125924
#
# ...

# %%
import random

# Randomize within each sample
def shuffle_sequence(row):
    coords = list(zip(
        [row[f'x{i}'] for i in range(1, slice_length + 1)],
        [row[f'y{i}'] for i in range(1, slice_length + 1)]
    ))
    random.shuffle(coords)  # shuffle in place
    xs, ys = zip(*coords)   # unzip back
    for i in range(slice_length):
        row[f'x{i+1}'] = xs[i]
        row[f'y{i+1}'] = ys[i]
    return row

# Apply to all rows
df_shuffled = df_final.copy().apply(shuffle_sequence, axis=1)

# %%
from matplotlib.lines import Line2D
from matplotlib.colors import to_rgb, to_hex

def generate_discrete_colormap(start_hex, end_hex, n_steps):
    start_rgb = np.array(to_rgb(start_hex))
    end_rgb = np.array(to_rgb(end_hex))
    return [to_hex(start_rgb + (end_rgb - start_rgb) * i / (n_steps - 1)) for i in range(n_steps)]

def plot_colored_sequence_discrete(ax, x_vals, y_vals, title):
    num_points = len(x_vals)
    colors = generate_discrete_colormap("#166088", "yellow", num_points)

    # Create segments for the lines between points
    points = np.array([x_vals, y_vals]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)

    # Line colors based on start point of each segment
    lc = LineCollection(segments, colors=colors[:-1], linewidths=2)
    ax.add_collection(lc)

    # Legend for steps
    legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[i],
                              markeredgecolor='black', label=f'Step {i+1}', markersize=8)
                       for i in range(num_points)]
    ax.legend(handles=legend_elements, title="Steps", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)

    ax.set_title(title)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.invert_yaxis()
    ax.set_aspect('equal')
    ax.set_xlim(min(x_vals) - 1, max(x_vals) + 1)
    ax.set_ylim(min(y_vals) - 1, max(y_vals) + 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection


task_name = 'task_4'
df_final_task = df_final[df_final['task'] == task_name].reset_index(drop=True)
df_shuffled_task = df_shuffled[df_shuffled['task'] == task_name].reset_index(drop=True)

# Choose a random row from the filtered data
#idx = np.random.randint(0, len(df_final_task))
#print(idx)
#idx = 225 #index open
idx = 231
# Extract coordinates
x_orig = [df_final_task.loc[idx, f'x{i}'] for i in range(1, slice_length + 1)]
y_orig = [df_final_task.loc[idx, f'y{i}'] for i in range(1, slice_length + 1)]

x_shuf = [df_shuffled_task.loc[idx, f'x{i}'] for i in range(1, slice_length + 1)]
y_shuf = [df_shuffled_task.loc[idx, f'y{i}'] for i in range(1, slice_length + 1)]

# Function to create colored line plots
def plot_colored_sequence(ax, x_vals, y_vals, title):
    # Prepare points and segments
    points = np.array([x_vals, y_vals]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)

    # Create a LineCollection with a colormap
    lc = LineCollection(segments, cmap='viridis', norm=plt.Normalize(0, len(segments)))
    lc.set_array(np.arange(len(segments)))
    lc.set_linewidth(2)

    line = ax.add_collection(lc)
    fig.colorbar(line, ax=ax, orientation='vertical', label='Step')

    ax.set_title(title)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.invert_yaxis()
    ax.set_aspect('equal')
    ax.set_xlim(min(x_vals) - 1, max(x_vals) + 1)
    ax.set_ylim(min(y_vals) - 1, max(y_vals) + 1)

# Plot side by side
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
titles = ['Original Sequence', 'Shuffled Sequence']

for ax, x_vals, y_vals, title in zip(axes, [x_orig, x_shuf], [y_orig, y_shuf], titles):
    plot_colored_sequence_discrete(ax, x_vals, y_vals, title)

plt.suptitle(f"Label: {df_final.loc[idx, 'label']}, Subject: {df_final.loc[idx, 'subject']}")
plt.tight_layout()
plt.savefig(f"/Users/sinakling/Desktop/classifier_input_up_closed_colored_pt_calib.pdf")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Define feature columns
feature_cols = [f'x{i}' for i in range(1, 10)] + [f'y{i}' for i in range(1, 10)]

df_final = df_shuffled

# Separate tasks
df_task_1 = df_final[df_final['task'] == "task_1"].copy()
df_task_2 = df_final[df_final['task'] == "task_2"].copy()
df_task_3 = df_final[df_final['task'] == "task_3"].copy()
df_task_4 = df_final[df_final['task'] == "task_4"].copy()

def run_loo_cv(df_task, task_name, save_dir):
    X = df_task[feature_cols].values
    y = df_task['label_encoded'].values
    groups = df_task['subject'].values

    # Compute baseline accuracy
    most_frequent_class = np.bincount(y).argmax()
    baseline_preds = np.full_like(y, most_frequent_class)
    baseline_acc = accuracy_score(y, baseline_preds)

    logo = LeaveOneGroupOut()
    subject_accuracies = {}
    conf_matrices = {}

    for train_idx, test_idx in logo.split(X, y, groups):
        subject_left_out = groups[test_idx][0]

        X_train, X_val = X[train_idx], X[test_idx]
        y_train, y_val = y[train_idx], y[test_idx]

        clf = LogisticRegression(max_iter=1000)
        clf.fit(X_train, y_train)

        y_pred = clf.predict(X_val)
        acc = accuracy_score(y_val, y_pred)

        subject_accuracies[subject_left_out] = acc

        # Train a classifier on all of df_task_1 for plotting
        X_plot = df_task_1[feature_cols].values
        y_plot = df_task_1['label_encoded'].values

        clf_plot = LogisticRegression(max_iter=1000)
        clf_plot.fit(X_plot, y_plot)
        # Confusion Matrix (as percent)
        cm = confusion_matrix(
            y_val, y_pred, labels=np.arange(len(df_final['label_encoded'].unique()))
        )

        # Normalize by row (i.e., true label) to get percent per class
        cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
        conf_matrices[subject_left_out] = cm_percent

        # Plot confusion matrix
        #plt.figure(figsize=(6, 5))
        #sns.heatmap(cm_percent, annot=True, fmt='.1f', cmap='Blues',
        #            xticklabels=np.unique(df_final['label']),
        #            yticklabels=np.unique(df_final['label']))
        #plt.xlabel("Predicted Label")
        #plt.ylabel("True Label")
        #plt.title(f"Confusion Matrix (% | {task_name} | Subject 0{subject_left_out})")
        #plt.savefig(f"{save_dir}/confusion_matrix_percent_sub-0{subject_left_out}_{task_name}_shuffled_pt_gaze.pdf")
        #plt.show()

    # Accuracy Summary
    df_acc = pd.DataFrame(subject_accuracies.items(), columns=["Subject", f"{task_name} Accuracy"])
    mean_acc = df_acc[f"{task_name} Accuracy"].mean()

    print(f"\n==== {task_name} ====")
    print(f"Baseline Accuracy (Majority Class): {baseline_acc:.2f}")
    print(f"Mean LOO-CV Accuracy: {mean_acc:.2f}")
    print(df_acc)

    #df_acc.to_csv(f"{save_dir}/accuracies_{task_name}_ordered_pt_gaze_new.csv", index=False)

    return df_acc, conf_matrices

# Run LOO-CV for both tasks separately
save_dir = "/Users/sinakling/Desktop"
df_acc_task_1, cm_task_1 = run_loo_cv(df_task_1, "task_1", save_dir)
df_acc_task_2, cm_task_2 = run_loo_cv(df_task_2, "task_2", save_dir)
df_acc_task_3, cm_task_3 = run_loo_cv(df_task_3, "task_3", save_dir)
df_acc_task_4, cm_task_4 = run_loo_cv(df_task_4, "task_4", save_dir)
# Out:
# ==== task_1 ====
# Baseline Accuracy (Majority Class): 0.25
# Mean LOO-CV Accuracy: 0.90
#     Subject  task_1 Accuracy
# 0         1         0.875000
# 1         2         0.500000
# 2         3         0.750000
# 3         4         0.875000
# 4         6         1.000000
# 5         7         1.000000
# 6         8         0.916667
# 7         9         0.916667
# 8        10         0.916667
# 9        11         1.000000
# 10       13         0.958333
# 11       14         1.000000
# 12       15         0.958333
# 13       16         0.875000
# 14       17         1.000000
#
# ==== task_2 ====
# Baseline Accuracy (Majority Class): 0.25
# Mean LOO-CV Accuracy: 0.90
#     Subject  task_2 Accuracy
# 0         1         1.000000
# 1         2         0.875000
# 2         3         0.875000
# 3         4         0.916667
# 4         6         0.916667
# 5         7         0.875000
# 6         8         0.916667
# 7         9         1.000000
# 8        10         0.833333
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Compute mean gaze position over the 9-frame sequences
df_final["mean_x"] = df_final[[f"x{i}" for i in range(1, 10)]].mean(axis=1)
df_final["mean_y"] = df_final[[f"y{i}" for i in range(1, 10)]].mean(axis=1)

# Filter for Task 1 and Task 4
tasks = {"Task 1": "task_1", "Task 4": "task_4"}

for task_name, task_label in tasks.items():
    task_mask = df_final['task'] == task_label
    X_task = df_final.loc[task_mask, ['mean_x', 'mean_y']].values
    y_task = df_final.loc[task_mask, 'label_encoded'].values

    # Train-test split (80% train, 20% test)
    X_train, X_test, y_train, y_test = train_test_split(X_task, y_task, test_size=0.2, random_state=42)

    # Train classifier
    clf = LogisticRegression(max_iter=1000)
    clf.fit(X_train, y_train)

    # Plot decision boundary
    xx, yy = np.meshgrid(np.linspace(X_task[:, 0].min()-1, X_task[:, 0].max()+1, 100),
                         np.linspace(X_task[:, 1].min()-1, X_task[:, 1].max()+1, 100))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(8, 6))
    plt.contourf(xx, yy, Z, alpha=0.3, cmap='coolwarm')
    sns.scatterplot(x=X_task[:, 0], y=X_task[:, 1], hue=y_task, palette='coolwarm', alpha=0.8)
    plt.xlabel("Mean X")
    plt.ylabel("Mean Y")
    plt.title(f"Decision Boundary for {task_name} (Mean Gaze Position)")
    plt.legend(title="Label Encoded")
    plt.savefig(f"{save_dir}/decision_boundary_{task_label}_closed_pt_gaze.pdf")
    plt.show()

# %%
import matplotlib.pyplot as plt
import math

def plot_triangle(ax, coords, color='blue'):
    """Plots a single triangle"""
    x = coords[:9] + [coords[0]]  # Close the triangle
    y = coords[9:] + [coords[0]]  # Close the triangle
    ax.plot(x, y, color=color, linestyle='solid')
    
# Number of samples to plot
num_samples = min(20, len(df_task_4))

# Define grid layout
ncols = 5  # Number of columns
nrows = math.ceil(num_samples / ncols)  # Compute required rows

# Create figure with more space
fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 3, nrows * 3))

# Flatten axes array for easy iteration
axes = axes.flatten()

for i, (index, row) in enumerate(df_task_4.iterrows()):
    if i >= num_samples:
        break

    # Train a model for plotting
    X_plot = df_task_4[feature_cols].values
    y_plot = df_task_4['label_encoded'].values

    clf_plot = LogisticRegression(max_iter=1000)
    clf_plot.fit(X_plot, y_plot)
    
    true_coords = row[feature_cols].tolist()
    predicted_label = clf_plot.predict([true_coords])[0]

    ax = axes[i]
    plot_triangle(ax, true_coords, color='blue')
    
    # Set title with subject + true label + predicted label
    ax.set_title(
        f"Sub-{row['subject']} | True: {row['label']}\nPred: {df_final[df_final['label_encoded'] == predicted_label].iloc[0]['label']}",
        fontsize=10
    )
    
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
 

# Hide unused subplots (if num_samples < total grid size)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.subplots_adjust(hspace=0.5, wspace=0.5)  # Adjust spacing
plt.savefig(f"/Users/sinakling/Desktop/triangles_examples_task_4.pdf")
plt.show()

# %%
def reshape_accuracy_df(df, task_num, model_name, order_type):
    df = df.rename(columns={f'task_{task_num} Accuracy': 'value',
                            'Subject': 'subject'})
    df['task'] = f'Task {task_num} Accuracy'
    df['model'] = model_name
    df['order'] = order_type
    return df[['subject', 'task', 'model', 'value', 'order']]

# %%
df_accuracies_task_1_ordered_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_1_ordered_pt_new.csv')
df_accuracies_task_2_ordered_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_2_ordered_pt_new.csv')
df_accuracies_task_3_ordered_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_3_ordered_pt_new.csv')
df_accuracies_task_4_ordered_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_4_ordered_pt_new.csv')

df_accuracies_task_1_shuffled_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_1_shuffled_pt_new.csv')
df_accuracies_task_2_shuffled_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_2_shuffled_pt_new.csv')
df_accuracies_task_3_shuffled_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_3_shuffled_pt_new.csv')
df_accuracies_task_4_shuffled_pt = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_4_shuffled_pt_new.csv')

df_accuracies_task_1_ordered_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_1_ordered_pt_calib_new.csv')
df_accuracies_task_2_ordered_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_2_ordered_pt_calib_new.csv')
df_accuracies_task_3_ordered_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_3_ordered_pt_calib_new.csv')
df_accuracies_task_4_ordered_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_4_ordered_pt_calib_new.csv')

df_accuracies_task_1_shuffled_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_1_shuffled_pt_calib_new.csv')
df_accuracies_task_2_shuffled_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_2_shuffled_pt_calib_new.csv')
df_accuracies_task_3_shuffled_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_3_shuffled_pt_calib_new.csv')
df_accuracies_task_4_shuffled_pt_calib = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_4_shuffled_pt_calib_new.csv')

df_accuracies_task_1_ordered_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_1_ordered_pt_gaze_new.csv')
df_accuracies_task_2_ordered_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_2_ordered_pt_gaze_new.csv')
df_accuracies_task_3_ordered_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_3_ordered_pt_gaze_new.csv')
df_accuracies_task_4_ordered_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_4_ordered_pt_gaze_new.csv')

df_accuracies_task_1_shuffled_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_1_shuffled_pt_gaze_new.csv')
df_accuracies_task_2_shuffled_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_2_shuffled_pt_gaze_new.csv')
df_accuracies_task_3_shuffled_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_3_shuffled_pt_gaze_new.csv')
df_accuracies_task_4_shuffled_pt_gaze = pd.read_csv('/Users/sinakling/Desktop/accuracies_task_4_shuffled_pt_gaze_new.csv')

# %%
all_dfs = []

# Add your actual DataFrame variables here
all_dfs.append(reshape_accuracy_df(df_accuracies_task_1_ordered_pt, task_num=1, model_name='pt', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_2_ordered_pt, task_num=2, model_name='pt', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_3_ordered_pt, task_num=3, model_name='pt', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_4_ordered_pt, task_num=4, model_name='pt', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_1_shuffled_pt, task_num=1, model_name='pt', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_2_shuffled_pt, task_num=2, model_name='pt', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_3_shuffled_pt, task_num=3, model_name='pt', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_4_shuffled_pt, task_num=4, model_name='pt', order_type='shuffled'))

all_dfs.append(reshape_accuracy_df(df_accuracies_task_1_ordered_pt_gaze, task_num=1, model_name='pt_gaze', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_2_ordered_pt_gaze, task_num=2, model_name='pt_gaze', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_3_ordered_pt_gaze, task_num=3, model_name='pt_gaze', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_4_ordered_pt_gaze, task_num=4, model_name='pt_gaze', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_1_shuffled_pt_gaze, task_num=1, model_name='pt_gaze', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_2_shuffled_pt_gaze, task_num=2, model_name='pt_gaze', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_3_shuffled_pt_gaze, task_num=3, model_name='pt_gaze', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_4_shuffled_pt_gaze, task_num=4, model_name='pt_gaze', order_type='shuffled'))

all_dfs.append(reshape_accuracy_df(df_accuracies_task_1_ordered_pt_calib, task_num=1, model_name='pt_calib', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_2_ordered_pt_calib, task_num=2, model_name='pt_calib', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_3_ordered_pt_calib, task_num=3, model_name='pt_calib', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_4_ordered_pt_calib, task_num=4, model_name='pt_calib', order_type='ordered'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_1_shuffled_pt_calib, task_num=1, model_name='pt_calib', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_2_shuffled_pt_calib, task_num=2, model_name='pt_calib', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_3_shuffled_pt_calib, task_num=3, model_name='pt_calib', order_type='shuffled'))
all_dfs.append(reshape_accuracy_df(df_accuracies_task_4_shuffled_pt_calib, task_num=4, model_name='pt_calib', order_type='shuffled'))


df_all_accuracies = pd.concat(all_dfs, ignore_index=True)


# Group by 'task', 'model', and 'order', and calculate the mean of 'value'
df_mean_accuracies = df_all_accuracies.groupby(['task', 'model', 'order'])['value'].mean().reset_index()

# Print the result
print(df_mean_accuracies)
# Out:
#                task     model     order     value
# 0   Task 1 Accuracy        pt   ordered  0.947222
# 1   Task 1 Accuracy        pt  shuffled  0.866667
# 2   Task 1 Accuracy  pt_calib   ordered  1.000000
# 3   Task 1 Accuracy  pt_calib  shuffled  0.877778
# 4   Task 1 Accuracy   pt_gaze   ordered  1.000000
# 5   Task 1 Accuracy   pt_gaze  shuffled  0.997222
# 6   Task 2 Accuracy        pt   ordered  0.958333
# 7   Task 2 Accuracy        pt  shuffled  0.808333
# 8   Task 2 Accuracy  pt_calib   ordered  1.000000
# 9   Task 2 Accuracy  pt_calib  shuffled  0.908333
# 10  Task 2 Accuracy   pt_gaze   ordered  1.000000
# 11  Task 2 Accuracy   pt_gaze  shuffled  0.947222
# 12  Task 3 Accuracy        pt   ordered  0.880556
# 13  Task 3 Accuracy        pt  shuffled  0.872222
# 14  Task 3 Accuracy  pt_calib   ordered  0.888889
# 15  Task 3 Accuracy  pt_calib  shuffled  0.875000
# 16  Task 3 Accuracy   pt_gaze   ordered  0.905556
# 17  Task 3 Accuracy   pt_gaze  shuffled  0.886111
# ...

# %%
df_all_accuracies['subject'] = df_all_accuracies['subject'].apply(lambda x: f"sub-{int(x):02d}")

print(df_all_accuracies)
# Out:
#     subject             task     model     value     order
# 0    sub-01  Task 1 Accuracy        pt  1.000000   ordered
# 1    sub-02  Task 1 Accuracy        pt  0.208333   ordered
# 2    sub-03  Task 1 Accuracy        pt  1.000000   ordered
# 3    sub-04  Task 1 Accuracy        pt  1.000000   ordered
# 4    sub-05  Task 1 Accuracy        pt  1.000000   ordered
# ..      ...              ...       ...       ...       ...
# 355  sub-13  Task 4 Accuracy  pt_calib  0.666667  shuffled
# 356  sub-14  Task 4 Accuracy  pt_calib  0.625000  shuffled
# 357  sub-15  Task 4 Accuracy  pt_calib  0.625000  shuffled
# 358  sub-16  Task 4 Accuracy  pt_calib  0.583333  shuffled
# 359  sub-17  Task 4 Accuracy  pt_calib  0.500000  shuffled
#
# [360 rows x 5 columns]

# %%
from scipy.stats import permutation_test
import pandas as pd

def paired_permutation_tests(df, model_a, model_b):
    """
    Run paired permutation tests between two models for each task and order combination.

    Parameters:
        df (pd.DataFrame): DataFrame with columns ['subject', 'task', 'model', 'order', 'value']
        model_a (str): Name of the first model
        model_b (str): Name of the second model

    Returns:
        pd.DataFrame: A DataFrame with task, order, p-value, and effect size (mean diff)
    """
    results = []

    grouped = df.groupby(['task', 'order'])
    for (task, order), group in grouped:
        # Pivot to get one row per subject, one column per model
        pivoted = group[group['model'].isin([model_a, model_b])].pivot(index='subject', columns='model', values='value')

        # Drop any rows with NaNs (subjects missing from either model)
        pivoted = pivoted.dropna()

        if pivoted.shape[0] < 2:
            continue  # skip if not enough subjects

        a_values = pivoted[model_a].values
        b_values = pivoted[model_b].values

        # Paired permutation test using mean difference as statistic
        result = permutation_test((a_values, b_values),
                                  statistic=lambda x, y: (x - y).mean(),
                                  permutation_type='samples',
                                  vectorized=False,
                                  alternative='less',
                                  n_resamples=10000)

        results.append({
            'task': task,
            'order': order,
            'model_a': model_a,
            'model_b': model_b,
            'mean_diff': (a_values - b_values).mean(),
            'p_value': result.pvalue,
            'n_subjects': len(pivoted)
        })

    return pd.DataFrame(results)

# %%
# Run paired permutation tests 
sig_df_pt_vs_calib = paired_permutation_tests(df_all_accuracies, model_a='pt', model_b='pt_calib')

# Run paired permutation tests for another pairing (e.g., pt vs pt_gaze) and append to the same dataframe
sig_df_pt_vs_gaze = paired_permutation_tests(df_all_accuracies, model_a='pt', model_b='pt_gaze')

# Append the results from both pairings
sig_df = pd.concat([sig_df_pt_vs_calib, sig_df_pt_vs_gaze], ignore_index=True)

# Show the combined dataframe with the significance results
print(sig_df)
# Out:
#                task     order model_a   model_b  mean_diff   p_value  \
# 0   Task 1 Accuracy   ordered      pt  pt_calib  -0.052778  0.500050
# 1   Task 1 Accuracy  shuffled      pt  pt_calib  -0.011111  0.380562
# 2   Task 2 Accuracy   ordered      pt  pt_calib  -0.041667  0.490651
# 3   Task 2 Accuracy  shuffled      pt  pt_calib  -0.100000  0.003500
# 4   Task 3 Accuracy   ordered      pt  pt_calib  -0.008333  0.484852
# 5   Task 3 Accuracy  shuffled      pt  pt_calib  -0.002778  0.504950
# 6   Task 4 Accuracy   ordered      pt  pt_calib  -0.002778  0.501950
# 7   Task 4 Accuracy  shuffled      pt  pt_calib  -0.033333  0.130787
# 8   Task 1 Accuracy   ordered      pt   pt_gaze  -0.052778  0.499450
# 9   Task 1 Accuracy  shuffled      pt   pt_gaze  -0.130556  0.000100
# 10  Task 2 Accuracy   ordered      pt   pt_gaze  -0.041667  0.489451
# 11  Task 2 Accuracy  shuffled      pt   pt_gaze  -0.138889  0.000700
# 12  Task 3 Accuracy   ordered      pt   pt_gaze  -0.025000  0.311969
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Colors and layout settings
ordered_color = "#4281A4"   # Blue
shuffled_color = "#7DBA84"  # Emerald
bar_width = 0.35

# Mapping of tasks to titles
task_titles = {
    "Task 1 Accuracy": "Eyes Open + Vision",
    "Task 2 Accuracy": "Eyes Blink + Vision",
    "Task 3 Accuracy": "Eyes Open + No Vision",
    "Task 4 Accuracy": "Eyes Closed + No Vision"
}

model_name_map = {
    "pt_calib": "DeepMreye + Calib",
    "pt_gaze": "DeepMreye + Closed",
    "pt": "DeepMreye"
}

# Create subplot figure
fig = make_subplots(rows=4, cols=2, subplot_titles=["Eyes Open + Vision", "Eyes Open + Vision", "Eyes Blink + Vision",  "Eyes Blink + Vision", "Eyes Open + No Vision", "Eyes Open + No Vision", "Eyes Closed + No Vision", "Eyes Closed + No Vision" ], horizontal_spacing=0.15, vertical_spacing=0.1)

# Iterate through tasks and models
task_list = [f"Task {i} Accuracy" for i in range(1, 5)]

for row, task in enumerate(task_list, start=1):
    for col, comparison in enumerate([("pt", "pt_calib"), ("pt", "pt_gaze")], start=1):
        model_a, model_b = comparison
        subset = df_all_accuracies[
            (df_all_accuracies["task"] == task) &
            (df_all_accuracies["model"].isin([model_a, model_b]))
        ]

        for i, order in enumerate(["ordered", "shuffled"]):
            df_order = subset[subset["order"] == order]
            means = df_order.groupby("model")["value"].mean() * 100
            stderrs = subset.groupby("model")["value"].sem().reindex([model_a, model_b]).values * 100

            x_vals = [model_name_map[model_a], model_name_map[model_b]]
            y_vals = [means.get(model_a, 0), means.get(model_b, 0)]
            color = ordered_color if order == "ordered" else shuffled_color

            # Positioning bars with some offset
            offset = -bar_width / 2 if order == "ordered" else bar_width / 2
            x_pos = [i + offset for i in range(len(x_vals))]

            fig.add_trace(go.Bar(
                x=x_pos,
                y=y_vals,
                error_y=dict(type='data', array=stderrs),
                text=[f"{v:.1f}" for v in y_vals],
                textposition="inside",
                insidetextanchor="start", 
                name=order.capitalize(),
                marker_color=color,
                width=bar_width,
                showlegend=(row == 1 and col == 1),
            ), row=row, col=col)

            # Check for significance
            sig_row = sig_df[
                (sig_df.task == task) &
                (sig_df.order == order) &
                (sig_df.model_a == model_a) &
                (sig_df.model_b == model_b)
            ]

            if not sig_row.empty and sig_row.iloc[0].p_value < 0.05:
                print(sig_row.iloc[0].p_value)
                # Draw a horizontal line between bar centers
                max_y = max(y_vals)
                line_y = max_y + 8  # Add space above bars

                fig.add_shape(
                    type="line",
                    x0=x_pos[0],
                    x1=x_pos[1],
                    y0=line_y,
                    y1=line_y,
                    line=dict(color="black", width=2),
                    row=row, col=col
                )

fig.update_layout(
    height=1600,
    width=1000,
    title_text="Model Comparison Across Tasks",
    template="simple_white",
    showlegend=True,
    font=dict(
        family="Helvetica Neue",  
        size=15,
        color="black"
    )
)

# Standardize all axes
for i in range(1, 5):  # Rows: tasks
    for j in range(1, 3):  # Columns: comparisons
        fig.update_yaxes(
            range=[0, 109],
            title_text="Classification Accuracy (%)",
            row=i, col=j
        )
        if j == 1:
            ticktext = ["DeepMReye", "DeepMReye + Calib"]
        else:  # j == 2
            ticktext = ["DeepMReye", "DeepMReye + Closed"]

        fig.update_xaxes(
            tickvals=[0, 1],
            ticktext=ticktext,
            row=i, col=j
        )

# Add chance level line
for i in range(1, 5):
    for j in range(1, 3):
        fig.add_shape(
            type="line",
            x0=-0.5,
            x1=1.5,
            y0=25,
            y1=25,
            line=dict(color="black", width=1, dash="dot"),
            row=i, col=j
        )

fig.show()
#fig.write_image("/Users/sinakling/Desktop/classifier_comparison.pdf")
# Out:
# 9.999000099990002e-05
# 0.0034996500349965005
# 0.0006999300069993001
# 0.0216978302169783

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Fixed model order
model_order = ["pt", "pt_calib", "pt_gaze"]

# Create subplot figure (one per task, with Ordered vs Shuffled groups)
fig = make_subplots(
    rows=2, cols=2, 
    subplot_titles=[task_titles[t] for t in task_list],
    horizontal_spacing=0.15, vertical_spacing=0.15
)

for idx, task in enumerate(task_list):
    row = idx // 2 + 1
    col = idx % 2 + 1
    
    for j, order in enumerate(["ordered", "shuffled"]):
        subset = df_all_accuracies[
            (df_all_accuracies["task"] == task) &
            (df_all_accuracies["order"] == order)
        ]
        
        means = subset.groupby("model")["value"].mean() * 100
        stderrs = subset.groupby("model")["value"].sem().reindex(model_order).values * 100
        
        y_vals = [means.get(m, 0) for m in model_order]
        tick_labels = [f"{order.capitalize()} - {model_name_map[m]}" for m in model_order]
        
        # Plot bars
        fig.add_trace(go.Bar(
            x=tick_labels,
            y=y_vals,
            error_y=dict(type='data', array=stderrs),
            text=[f"{v:.1f}" for v in y_vals],
            textposition="inside",
            insidetextanchor="start",
            marker_color=ordered_color if order == "ordered" else shuffled_color,
            width=0.35,
            name=f"{order.capitalize()} - {task_titles[task]}"
        ), row=row, col=col)
        
        # === Add significance bars ===
        x_positions = {m: i for i, m in enumerate(model_order)}
        
        for m1_i in range(len(model_order)):
            for m2_i in range(m1_i + 1, len(model_order)):
                model_a = model_order[m1_i]
                model_b = model_order[m2_i]
                
                sig_row = sig_df[
                    (sig_df.task == task) &
                    (sig_df.order == order) &
                    (
                        ((sig_df.model_a == model_a) & (sig_df.model_b == model_b)) |
                        ((sig_df.model_a == model_b) & (sig_df.model_b == model_a))
                    )
                ]
                
                if not sig_row.empty and sig_row.iloc[0].p_value < 0.05:
                    max_y = max(means.get(model_a, 0), means.get(model_b, 0))
                    line_y = max_y + 8
                    
                    fig.add_shape(
                        type="line",
                        x0=x_positions[model_a],
                        x1=x_positions[model_b],
                        y0=line_y,
                        y1=line_y,
                        line=dict(color="black", width=2),
                        row=row, col=col
                    )

    # Y-axis + chance line
    fig.update_yaxes(range=[0, 109], title_text="Accuracy (%)", row=row, col=col)
    fig.add_shape(
        type="line",
        x0=-0.5, x1=len(model_order)*2 - 0.5,
        y0=25, y1=25,
        line=dict(color="black", width=1, dash="dot"),
        row=row, col=col
    )

fig.update_layout(
    height=1000,
    width=1200,
    title_text="Model Comparison Across Tasks (Ordered vs Shuffled)",
    template="simple_white",
    showlegend=False,
    font=dict(family="Helvetica Neue", size=14, color="black"),
    barmode="group"
)

fig.show()
fig.write_image("/Users/sinakling/Desktop/classifier_comparison_grouped_new.pdf")

# %% [markdown]
# Figure X. Classification accuracies for decoding eye position across four task conditions. Participants performed eye movements forming rotating triangles under four visual conditions: (1) eyes open with vision, (2) eyes blinking with vision, (3) eyes open without vision, and (4) eyes closed without vision. A deep learning model (DeepMReye) was used to decode eye position, and classification performance was assessed using three model versions: the base model using only pretrained weights (deepmreye), a calibration-tuned model fine-tuned on an eyes-open calibration task (deepmreye + calib), and a task-tuned model fine-tuned on the triangle task including eyes-closed segments (deepmreye + closed). To control for sequence-based decoding (e.g., due to the predictable structure of the triangle task), trial orders were shuffled to test for potential order effects. Accuracies reflect within-task training and testing.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Setup
task_names = ["Task 1 Accuracy", "Task 4 Accuracy"]
task_labels = ["<b>Eyes Open</b>", "<b>Eyes Closed</b>"]
model_order = ["pt_gaze", "pt_calib", "pt"]
bar_color = 'rgba(66, 129, 164, 0.25)' 

model_name_map = {
    "pt_calib": "DeepMreye + Calib",
    "pt_gaze": "DeepMreye + Closed",
    "pt": "DeepMreye"
}

orders = ["ordered", "shuffled"]

for order_type in orders:
    fig = make_subplots(
        rows=2, cols=1,
        shared_xaxes=False,
        vertical_spacing=0.15,
        subplot_titles=task_labels
    )

    for i, task in enumerate(task_names):
        row = i + 1

        df_plot = df_all_accuracies[
            (df_all_accuracies["task"] == task) &
            (df_all_accuracies["order"] == order_type) &
            (df_all_accuracies["model"].isin(model_order))
        ]

        df_pivot = df_plot.pivot(index="subject", columns="model", values="value")[model_order].dropna()

        means = df_pivot.mean() * 100
        stderrs = df_pivot.sem() * 100
        y_vals = [model_name_map[m] for m in model_order]

        fig.add_trace(go.Bar(
            y=y_vals,
            x=means.values,
            error_x=dict(type="data", array=stderrs.values),
            orientation='h',
            marker_color=bar_color,
            width=0.4,
            showlegend=False
        ), row=row, col=1)

        offset_counter = 0
        for j in range(len(model_order)):
            for k in range(j + 1, len(model_order)):
                model_a = model_order[j]
                model_b = model_order[k]

                sig_row = sig_df[
                    ((sig_df.task == task) &
                     (sig_df.order == order_type) &  # Filter by current order!
                     (((sig_df.model_a == model_a) & (sig_df.model_b == model_b)) |
                      ((sig_df.model_a == model_b) & (sig_df.model_b == model_a))))
                ]

                if not sig_row.empty and sig_row.iloc[0].p_value < 0.05:
                    y0 = model_name_map[model_a]
                    y1 = model_name_map[model_b]
                    y_indices = {name: idx for idx, name in enumerate(y_vals)}
                    y0_idx = y_indices[y0]
                    y1_idx = y_indices[y1]
                    y_mid = y_vals[int(round((y0_idx + y1_idx) / 2))]

                    x0 = means[model_a]
                    x1 = means[model_b]
                    x_max = max(x0, x1)
                    line_x = x_max + offset_counter * 0.1

                    fig.add_shape(
                        type="line",
                        x0=line_x, x1=line_x,
                        y0=y0, y1=y1,
                        xref='x'+str(row) if row > 1 else 'x',
                        yref='y'+str(row) if row > 1 else 'y',
                        line=dict(color="black", width=1),
                        row=row, col=1
                    )

                    for y in [y0, y1]:
                        fig.add_shape(
                            type="line",
                            x0=line_x - 0.05, x1=line_x,
                            y0=y, y1=y,
                            xref='x'+str(row) if row > 1 else 'x',
                            yref='y'+str(row) if row > 1 else 'y',
                            line=dict(color="black", width=1),
                            row=row, col=1
                        )

                    fig.add_trace(go.Scatter(
                        x=[line_x],
                        y=[y_mid],
                        text=["*"],
                        mode="text",
                        textposition="middle left",
                        showlegend=False
                    ), row=row, col=1)

                    offset_counter += 1

    fig.update_layout(
        height=1000,
        width=900,
        title_text=f"EE Across Tasks and Models — {order_type.title()}",
        template="simple_white",
        showlegend=False,
        font=dict(size=16, family="Arial"),
        margin=dict(t=120)
    )

    for i in range(1, 3):
        fig.update_xaxes(range=[0, 100], title_text="Euclidean Error (dva)", row=i, col=1)
        fig.update_yaxes(title_text="", row=i, col=1)

    fig.show()
    # Uncomment to save:
    fig.write_image(f"/Users/sinakling/Desktop/EE_barplot_{order_type}.pdf")

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

order_to_plot = "ordered"
# Define color and name mappings
model_name_map = {
    "pt": "DeepMreye",
    "pt_calib": "DeepMreye + Calib",
    "pt_gaze": "DeepMreye + Closed"
}

ordered_color = "#4281A4"
shuffled_color = "#7DBA84"

# Define subject-specific colors
colormap_subject_dict = {
    'sub-01': '#AA0DFE', 'sub-02': '#3283FE', 'sub-03': '#85660D', 'sub-04': '#782AB6',
    'sub-05': '#565656', 'sub-06': '#1C8356', 'sub-07': '#16FF32', 'sub-08': '#F7E1A0',
    'sub-09': '#E2E2E2', 'sub-11': '#1CBE4F', 'sub-13': '#DEA0FD', 'sub-14': '#FBE426', 
    'sub-15': '#325A9B', 'sub-16': '#FEAF16', 'sub-17': '#F8A19F'
}

# Define tasks and their labels
task_labels = [
    "Eyes Open + Vision",
    "Eyes Blink + Vision",
    "Eyes Open + No Vision",
    "Eyes Closed + No Vision"
]
task_names = [
    "Task 1 Accuracy",
    "Task 2 Accuracy",
    "Task 3 Accuracy",
    "Task 4 Accuracy"
]

# Create subplot figure
fig = make_subplots(rows=4, cols=2, subplot_titles=[f"{label}" for label in task_labels for _ in range(2)])

# Set model comparisons per column
comparisons = [("pt", "pt_calib"), ("pt", "pt_gaze")]

shown_subjects = set()

# Loop through tasks and comparisons
for i, task in enumerate(task_names):
    for j, (model_a, model_b) in enumerate(comparisons):
        row = i + 1
        col = j + 1

        # Filter the dataframe for ordered condition
        df_plot = df_all_accuracies[
            (df_all_accuracies["task"] == task) &
            (df_all_accuracies["order"] == order_to_plot) &
            (df_all_accuracies["model"].isin([model_a, model_b]))
        ]

        # Pivot to have models as columns and subjects as rows
        df_pivot = df_plot.pivot(index="subject", columns="model", values="value")[[model_a, model_b]]

        # Plot bars
        means = df_pivot.mean()
        stderrs = df_pivot.sem()
        x_vals = [0, 1]

        fig.add_trace(go.Bar(
            x=x_vals,
            y=means.values * 100,
            error_y=dict(type="data", array=stderrs.values * 100),
            text=[f"{v:.1f}" for v in means.values * 100],
            textposition="inside",
            insidetextanchor="start",
            name="Ordered",
            marker_color=ordered_color,
            width=0.35,
            showlegend=(row == 1 and col == 1),
        ), row=row, col=col)

        # Adding lines connecting subjects
        for subject, row_data in df_pivot.iterrows():
            color = colormap_subject_dict.get(subject, 'gray')
            show_legend = subject not in shown_subjects
            shown_subjects.add(subject)

            fig.add_trace(go.Scatter(
                x=x_vals,
                y=row_data.values*100,
                mode='lines+markers',
                line=dict(color=color, width=1.5),
                marker=dict(size=4),
                name=subject,
                opacity=0.9,
                showlegend=show_legend
            ), row=row, col=col)

        # Add significance marker if p < 0.05
        sig_row = sig_df[
            (sig_df.task == task) &
            (sig_df.model_a == model_a) &
            (sig_df.model_b == model_b)
        ]

        if not sig_row.empty and sig_row.iloc[0].p_value < 0.05:
            y_vals = means.values
            max_y = max(y_vals)
            line_y = max_y + 8

            fig.add_shape(
                type="line",
                x0=0,
                x1=1,
                y0=line_y,
                y1=line_y,
                line=dict(color="black", width=1),
                row=row, col=col
            )
            fig.add_trace(go.Scatter(
                x=[0.5],
                y=[line_y + 0.9],
                text=["*"],
                mode="text",
                showlegend=False
            ), row=row, col=col)

            # Add chance line at 25%
        fig.add_shape(
            type="line",
            x0=-0.5, x1=1.5,
            y0=25, y1=25,
            line=dict(color="black", dash="dot"),
            xref=f"x{(row - 1) * 2 + col}",
            yref=f"y{(row - 1) * 2 + col}"
        )

# Final layout adjustments
fig.update_layout(
    height=1800,  # More vertical space for connecting lines
    width=1000,
    title_text="Model Comparison Across Tasks (Ordered)",
    template="simple_white",
    showlegend=True,
    font=dict(size=16, family="Arial"),
    margin=dict(t=150)  # Increase top margin
)

# Update axes
for i in range(1, 5):
    for j in range(1, 3):
        fig.update_yaxes(range=[0, 109], title_text="Classification Accuracy (%)", row=i, col=j)
        fig.update_xaxes(
            tickvals=[0, 1],
            ticktext=[model_name_map["pt"], model_name_map["pt_calib"] if j == 1 else model_name_map["pt_gaze"]],
            row=i, col=j
        )

fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

order_to_plot = "shuffled"
# Define color and name mappings
model_name_map = {
    "pt": "DeepMreye",
    "pt_calib": "DeepMreye + Calib",
    "pt_gaze": "DeepMreye + Closed"
}

ordered_color = "#4281A4"
shuffled_color = "#7DBA84"

# Define subject-specific colors
colormap_subject_dict = {
    'sub-01': '#AA0DFE', 'sub-02': '#3283FE', 'sub-03': '#85660D', 'sub-04': '#782AB6',
    'sub-05': '#565656', 'sub-06': '#1C8356', 'sub-07': '#16FF32', 'sub-08': '#F7E1A0',
    'sub-09': '#E2E2E2', 'sub-11': '#1CBE4F', 'sub-13': '#DEA0FD', 'sub-14': '#FBE426', 
    'sub-15': '#325A9B', 'sub-16': '#FEAF16', 'sub-17': '#F8A19F'
}

# Define tasks and their labels
task_labels = [
    "Eyes Open + Vision",
    "Eyes Blink + Vision",
    "Eyes Open + No Vision",
    "Eyes Closed + No Vision"
]
task_names = [
    "Task 1 Accuracy",
    "Task 2 Accuracy",
    "Task 3 Accuracy",
    "Task 4 Accuracy"
]

# Create subplot figure
fig = make_subplots(rows=4, cols=2, subplot_titles=[f"{label}" for label in task_labels for _ in range(2)])

# Set model comparisons per column
comparisons = [("pt", "pt_calib"), ("pt", "pt_gaze")]

shown_subjects = set()

# Loop through tasks and comparisons
for i, task in enumerate(task_names):
    for j, (model_a, model_b) in enumerate(comparisons):
        row = i + 1
        col = j + 1

        # Filter the dataframe for ordered condition
        df_plot = df_all_accuracies[
            (df_all_accuracies["task"] == task) &
            (df_all_accuracies["order"] == order_to_plot) &
            (df_all_accuracies["model"].isin([model_a, model_b]))
        ]

        # Pivot to have models as columns and subjects as rows
        df_pivot = df_plot.pivot(index="subject", columns="model", values="value")[[model_a, model_b]]

        # Plot bars
        means = df_pivot.mean()
        stderrs = df_pivot.sem()
        x_vals = [0, 1]

        fig.add_trace(go.Bar(
            x=x_vals,
            y=means.values * 100,
            error_y=dict(type="data", array=stderrs.values * 100),
            text=[f"{v:.1f}" for v in means.values * 100],
            textposition="inside",
            insidetextanchor="start",
            name=order_to_plot,
            marker_color=shuffled_color,
            width=0.35,
            showlegend=(row == 1 and col == 1),
        ), row=row, col=col)

        # Adding lines connecting subjects
        for subject, row_data in df_pivot.iterrows():
            color = colormap_subject_dict.get(subject, 'gray')
            show_legend = subject not in shown_subjects
            shown_subjects.add(subject)

            fig.add_trace(go.Scatter(
                x=x_vals,
                y=row_data.values*100,
                mode='lines+markers',
                line=dict(color=color, width=1.5),
                marker=dict(size=4),
                name=subject,
                opacity=0.9,
                showlegend=show_legend
            ), row=row, col=col)

        # Add significance marker if p < 0.05
        sig_row = sig_df[
            (sig_df.task == task) &
            (sig_df.model_a == model_a) &
            (sig_df.model_b == model_b)
        ]

        if not sig_row.empty and sig_row.iloc[0].p_value < 0.05:
            y_vals = means.values
            max_y = max(y_vals)
            line_y = max_y + 8

            fig.add_shape(
                type="line",
                x0=0,
                x1=1,
                y0=line_y,
                y1=line_y,
                line=dict(color="black", width=1),
                row=row, col=col
            )
            fig.add_trace(go.Scatter(
                x=[0.5],
                y=[line_y + 0.9],
                text=["*"],
                mode="text",
                showlegend=False
            ), row=row, col=col)

        # Add chance line at 25%
        fig.add_shape(
            type="line",
            x0=-0.5, x1=1.5,
            y0=25, y1=25,
            line=dict(color="black", dash="dot"),
            xref=f"x{(row - 1) * 2 + col}",
            yref=f"y{(row - 1) * 2 + col}"
        )

# Final layout adjustments
fig.update_layout(
    height=1800,  # More vertical space for connecting lines
    width=1000,
    title_text=f"Model Comparison Across Tasks({order_to_plot})",
    template="simple_white",
    showlegend=True,
    font=dict(size=16, family="Arial"),
    margin=dict(t=150)  # Increase top margin
)

# Update axes
for i in range(1, 5):
    for j in range(1, 3):
        fig.update_yaxes(range=[0, 109], title_text="Classification Accuracy (%)", row=i, col=j)
        fig.update_xaxes(
            tickvals=[0, 1],
            ticktext=[model_name_map["pt"], model_name_map["pt_calib"] if j == 1 else model_name_map["pt_gaze"]],
            row=i, col=j
        )

fig.show()
